# %% [markdown]
# # <font color='red'> <b>INTRODUCTION TO C LANGUAGE</b></font>

# %% [markdown]
# <b>C is a general-purpose high level language that was originally developed by
# [Dennis Ritchie](https://en.wikipedia.org/wiki/Dennis_Ritchie) for the Unix operating system.<br> It was first implemented on the Digital Eqquipment Corporation PDP-11 computer in 1972. The [Unix operating system](https://en.wikipedia.org/wiki/Unix) and virtually all Unix applications are written in the C language</b>

# %% [markdown]
# # Idea of Algorithm

# %% [markdown]
# <B>Algorithm is a step-by-step procedure, which defines a set of instructions to be executed in a certain order to get the desired output. Algorithms are generally created independent of underlying languages, i.e. an algorithm can be implemented in more than one programming language<b>.<br>
#     ![algo.png](attachment:algo.png)

# %% [markdown]
# ##### -example of algorithm

# %% [markdown]
# Problem − Design an algorithm to add two numbers and display the result.
#
# Step 1 − START
#
# Step 2 − declare three integers a, b & c
#
# Step 3 − define values of a & b
#
# Step 4 − add values of a & b
#
# Step 5 − store output of step 4 to c
#
# Step 6 − print c
#
# Step 7 − STOP

# %% [markdown]
# # Flowchart and Pseudocode

# %% [markdown]
# <b>A flowchart is a schematic representation of an algorithm or a stepwise process, showing the steps as boxes of various kinds, and their order by connecting these with arrows. Flowcharts are used in designing or documenting a process or program.</b>

# %% [markdown]
# ![flowchart-3.png](attachment:flowchart-3.png)

# %% [markdown]
# ### PSEUDOCODE

# %% [markdown]
# <b>Pseudo code is a term which is often used in programming and algorithm based fields. It is a methodology that allows the programmer to represent the implementation of an algorithm. Simply, we can say that it’s the cooked up representation of an algorithm.</b>

# %% [markdown]
# ##### example of pseudocode

# %% [markdown]
#  if "1"
#     print response
#         "I am case 1"
#
# if "2"
#     print response
#         "I am case 2"

# %% [markdown]
# #  Introduction to Programming Language Concepts

# %% [markdown]
# <b>Binary information is sometimes also referred to as machine language since it represents the most fundamental level of information stored in a computer system. At a physical level, the 0s and 1s are stored in the central processing unit of a computer system using transistors</b>

# %% [markdown]
# #### what is a complier and what does it do ?

# %% [markdown]
# <b>A compiler is a special program that processes statements written in a particular programming language and turns them into machine language or "code" that a computer's processor uses. Typically, a programmer writes language statements in a language such as Pascal or C one line at a time using an editor</b>

# %% [markdown]
# ![nptel5.png](attachment:nptel5.png)

# %% [markdown]
# ## quiz time
#   ## [click here](https://forms.gle/zaG7HRddzfMdXip19)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------- <B><font color='yellow'><B>[NEXT CHAP](http://localhost:8888/notebooks/source/myproject2/Chapter%202.ipynb)</b></font>
